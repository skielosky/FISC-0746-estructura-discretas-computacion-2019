# %%
from collections import defaultdict, namedtuple, Counter, deque
import csv
import random
from urllib.request import urlretrieve

# %%
movie_data = 'https://raw.githubusercontent.com/pybites/challenges/solutions/13/movie_metadata.csv'
movies_csv = 'movies.csv'
urlretrieve(movie_data, movies_csv)
# Out:
# ('movies.csv', <http.client.HTTPMessage at 0x193a6f102b0>)

# %%
Movie = namedtuple('Movie', 'title year score')

# %%
def get_movies_by_director(data=movies_csv):
    """Extracts all movies from csv and stores them in a dictionary
       where keys are directors, and values is a list of movies (named tuples)"""
    directors = defaultdict(list)
    with open(data, encoding='utf-8') as f:
        for line in csv.DictReader(f):
            try:
                director = line['director_name']
                movie = line['movie_title'].replace('\xa0', '')
                year = int(line['title_year'])
                score = float(line['imdb_score'])
            except ValueError:
                continue

            m = Movie(title=movie, year=year, score=score)
            directors[director].append(m)

    return directors

# %%
directors = get_movies_by_director()

# %%
len(directors)
# Out:
# 2395

# %%
directors['Quentin Tarantino']
# Out:
# [Movie(title='Django Unchained', year=2012, score=8.5),
#  Movie(title='Inglourious Basterds', year=2009, score=8.3),
#  Movie(title='The Hateful Eight', year=2015, score=7.9),
#  Movie(title='Kill Bill: Vol. 1', year=2003, score=8.1),
#  Movie(title='Kill Bill: Vol. 2', year=2004, score=8.0),
#  Movie(title='Jackie Brown', year=1997, score=7.5),
#  Movie(title='Pulp Fiction', year=1994, score=8.9),
#  Movie(title='Reservoir Dogs', year=1992, score=8.4)]

# %%
directors
# Out:
# defaultdict(list,
#             {'James Cameron': [Movie(title='Avatar', year=2009, score=7.9),
#               Movie(title='Titanic', year=1997, score=7.7),
#               Movie(title='Terminator 2: Judgment Day', year=1991, score=8.5),
#               Movie(title='True Lies', year=1994, score=7.2),
#               Movie(title='The Abyss', year=1989, score=7.6),
#               Movie(title='Aliens', year=1986, score=8.4),
#               Movie(title='The Terminator', year=1984, score=8.1)],
#              'Gore Verbinski': [Movie(title="Pirates of the Caribbean: At World's End", year=2007, score=7.1),
#               Movie(title="Pirates of the Caribbean: Dead Man's Chest", year=2006, score=7.3),
#               Movie(title='The Lone Ranger', year=2013, score=6.5),
#               Movie(title='Rango', year=2011, score=7.2),
#               Movie(title='Pirates of the Caribbean: The Curse of the Black Pearl', year=2003, score=8.1),
#               Movie(title='The Mexican', year=2001, score=6.1),
#               Movie(title='The Weather Man', year=2005, score=6.6)],
#              'Sam Mendes': [Movie(title='Spectre', year=2015, score=6.8),
#               Movie(title='Skyfall', year=2012, score=7.8),
#               Movie(title='Road to Perdition', year=2002, score=7.7),
#               Movie(title='Jarhead', year=2005, score=7.1),
#               Movie(title='Revolutionary Road', year=2008, score=7.3),
#               Movie(title='Away We Go', year=2009, score=7.1),
#               Movie(title='American Beauty', year=1999, score=8.4),
#               Movie(title='Skyfall', year=2012, score=7.8)],
#              'Christopher Nolan': [Movie(title='The Dark Knight Rises', year=2012, score=8.5),
#               Movie(title='The Dark Knight', year=2008, score=9.0),
#               Movie(title='Interstellar', year=2014, score=8.6),
#               Movie(title='Inception', year=2010, score=8.8),
#               Movie(title='Batman Begins', year=2005, score=8.3),
#               Movie(title='Insomnia', year=2002, score=7.2),
#               Movie(title='The Prestige', year=2006, score=8.5),
#               Movie(title='Memento', year=2000, score=8.5)],
#              'Andrew Stanton': [Movie(title='John Carter', year=2012, score=6.6),
#               Movie(title='WALL·E', year=2008, score=8.4),
#               Movie(title='Finding Nemo', year=2003, score=8.2)],
#              'Sam Raimi': [Movie(title='Spider-Man 3', year=2007, score=6.2),
#               Movie(title='Spider-Man 2', year=2004, score=7.3),
#               Movie(title='Oz the Great and Powerful', year=2013, score=6.4),
#               Movie(title='Spider-Man', year=2002, score=7.3),
#               Movie(title='For Love of the Game', year=1999, score=6.5),
#               Movie(title='The Quick and the Dead', year=1995, score=6.4),
#               Movie(title='Drag Me to Hell', year=2009, score=6.6),
#               Movie(title='A Simple Plan', year=1998, score=7.5),
#               Movie(title='Army of Darkness', year=1992, score=7.6),
#               Movie(title='Spider-Man 3', year=2007, score=6.2),
#               Movie(title='Evil Dead II', year=1987, score=7.8),
#               Movie(title='Oz the Great and Powerful', year=2013, score=6.4),
#               Movie(title='The Evil Dead', year=1981, score=7.6)],
#              'Nathan Greno': [Movie(title='Tangled', year=2010, score=7.8)],
#              'Joss Whedon': [Movie(title='Avengers: Age of Ultron', year=2015, score=7.5),
#               Movie(title='The Avengers', year=2012, score=8.1),
#               Movie(title='The Avengers', year=2012, score=8.1),
#               Movie(title='Serenity', year=2005, score=8.0)],
#              'David Yates': [Movie(title='Harry Potter and the Half-Blood Prince', year=2009, score=7.5),
#               Movie(title='The Legend of Tarzan', year=2016, score=6.6),
#               Movie(title='Harry Potter and the Order of the Phoenix', year=2007, score=7.5),
#               Movie(title='The Legend of Tarzan', year=2016, score=6.6)],
#              'Zack Snyder': [Movie(title='Batman v Superman: Dawn of Justice', year=2016, score=6.9),
#               Movie(title='Man of Steel', year=2013, score=7.2),
#               Movie(title='Watchmen', year=2009, score=7.7),
#               Movie(title="Legend of the Guardians: The Owls of Ga'Hoole", year=2010, score=7.0),
#               Movie(title='Sucker Punch', year=2011, score=6.1),
#               Movie(title='300', year=2006, score=7.7),
#               Movie(title='Dawn of the Dead', year=2004, score=7.4),
#               Movie(title='Dawn of the Dead', year=2004, score=7.4)],
#              'Bryan Singer': [Movie(title='Superman Returns', year=2006, score=6.1),
#               Movie(title='X-Men: Days of Future Past', year=2014, score=8.0),
#               Movie(title='Jack the Giant Slayer', year=2013, score=6.3),
#               Movie(title='X-Men: Apocalypse', year=2016, score=7.3),
#               Movie(title='X-Men 2', year=2003, score=7.5),
#               Movie(title='Valkyrie', year=2008, score=7.1),
#               Movie(title='X-Men', year=2000, score=7.4),
#               Movie(title='The Usual Suspects', year=1995, score=8.6)],
#              'Marc Forster': [Movie(title='Quantum of Solace', year=2008, score=6.7),
#               Movie(title='World War Z', year=2013, score=7.0),
#               Movie(title='Stranger Than Fiction', year=2006, score=7.6),
#               Movie(title='Machine Gun Preacher', year=2011, score=6.8),
#               Movie(title='Finding Neverland', year=2004, score=7.8),
#               Movie(title='The Kite Runner', year=2007, score=7.6),
#               Movie(title="Monster's Ball", year=2001, score=7.1),
#               Movie(title='Everything Put Together', year=2000, score=6.6)],
#              'Andrew Adamson': [Movie(title='The Chronicles of Narnia: Prince Caspian', year=2008, score=6.6),
#               Movie(title='The Chronicles of Narnia: The Lion, the Witch and the Wardrobe', year=2005, score=6.9),
#               Movie(title='Shrek 2', year=2004, score=7.2),
#               Movie(title='Shrek', year=2001, score=7.9),
#               Movie(title='Cirque du Soleil: Worlds Away', year=2012, score=6.8)],
#              'Rob Marshall': [Movie(title='Pirates of the Caribbean: On Stranger Tides', year=2011, score=6.7),
#               Movie(title='Memoirs of a Geisha', year=2005, score=7.3),
#               Movie(title='Nine', year=2009, score=5.8),
#               Movie(title='Into the Woods', year=2014, score=6.0),
#               Movie(title='Chicago', year=2002, score=7.2)],
#              'Barry Sonnenfeld': [Movie(title='Men in Black 3', year=2012, score=6.8),
#               Movie(title='Wild Wild West', year=1999, score=4.8),
#               Movie(title='Men in Black II', year=2002, score=6.1),
#               Movie(title='Men in Black', year=1997, score=7.3),
#               Movie(title='Big Trouble', year=2002, score=6.5),
#               Movie(title='Get Shorty', year=1995, score=6.9),
#               Movie(title='The Addams Family', year=1991, score=6.8)],
#              'Peter Jackson': [Movie(title='The Hobbit: The Battle of the Five Armies', year=2014, score=7.5),
#               Movie(title='The Hobbit: The Desolation of Smaug', year=2013, score=7.9),
#               Movie(title='King Kong', year=2005, score=7.2),
#               Movie(title='The Hobbit: An Unexpected Journey', year=2012, score=7.9),
#               Movie(title='The Lord of the Rings: The Fellowship of the Ring', year=2001, score=8.8),
#               Movie(title='The Lovely Bones', year=2009, score=6.7),
#               Movie(title='The Lord of the Rings: The Return of the King', year=2003, score=8.9),
#               Movie(title='The Lord of the Rings: The Two Towers', year=2002, score=8.7),
#               Movie(title='King Kong', year=2005, score=7.2),
#               Movie(title='Heavenly Creatures', year=1994, score=7.4),
#               Movie(title='The Lovely Bones', year=2009, score=6.7),
#               Movie(title='King Kong', year=2005, score=7.2)],
#              'Marc Webb': [Movie(title='The Amazing Spider-Man', year=2012, score=7.0),
#               Movie(title='The Amazing Spider-Man 2', year=2014, score=6.7),
#               Movie(title='500 Days of Summer', year=2009, score=7.7)],
#              'Ridley Scott': [Movie(title='Robin Hood', year=2010, score=6.7),
#               Movie(title='Exodus: Gods and Kings', year=2014, score=6.1),
#               Movie(title='Prometheus', year=2012, score=7.0),
#               Movie(title='Kingdom of Heaven', year=2005, score=7.2),
#               Movie(title='The Martian', year=2015, score=8.1),
#               Movie(title='Gladiator', year=2000, score=8.5),
#               Movie(title='American Gangster', year=2007, score=7.8),
#               Movie(title='Black Hawk Down', year=2001, score=7.7),
#               Movie(title='Body of Lies', year=2008, score=7.1),
#               Movie(title='G.I. Jane', year=1997, score=5.8),
#               Movie(title='White Squall', year=1996, score=6.6),
#               Movie(title='A Good Year', year=2006, score=6.9),
#               Movie(title='Black Rain', year=1989, score=6.6),
#               Movie(title='Blade Runner', year=1982, score=8.2),
#               Movie(title='The Counselor', year=2013, score=5.3),
#               Movie(title='Alien', year=1979, score=8.5),
#               Movie(title='Exodus: Gods and Kings', year=2014, score=6.1)],
#              'Chris Weitz': [Movie(title='The Golden Compass', year=2007, score=6.1),
#               Movie(title='The Twilight Saga: New Moon', year=2009, score=4.6),
#               Movie(title='Down to Earth', year=2001, score=5.4),
#               Movie(title='About a Boy', year=2002, score=7.1),
#               Movie(title='A Better Life', year=2011, score=7.2)],
#              'Anthony Russo': [Movie(title='Captain America: Civil War', year=2016, score=8.2),
#               Movie(title='Captain America: The Winter Soldier', year=2014, score=7.8),
#               Movie(title='You, Me and Dupree', year=2006, score=5.6),
#               Movie(title='Welcome to Collinwood', year=2002, score=6.4)],
#              'Peter Berg': [Movie(title='Battleship', year=2012, score=5.9),
#               Movie(title='Hancock', year=2008, score=6.4),
#               Movie(title='The Rundown', year=2003, score=6.7),
#               Movie(title='The Kingdom', year=2007, score=7.1),
#               Movie(title='Lone Survivor', year=2013, score=7.6),
#               Movie(title='Very Bad Things', year=1998, score=6.3)],
#              'Colin Trevorrow': [Movie(title='Jurassic World', year=2015, score=7.0),
#               Movie(title='Safety Not Guaranteed', year=2012, score=7.0)],
#              'Shane Black': [Movie(title='Iron Man 3', year=2013, score=7.2),
#               Movie(title='Kiss Kiss Bang Bang', year=2005, score=7.6)],
#              'Tim Burton': [Movie(title='Alice in Wonderland', year=2010, score=6.5),
#               Movie(title='Charlie and the Chocolate Factory', year=2005, score=6.7),
#               Movie(title='Dark Shadows', year=2012, score=6.2),
#               Movie(title='Planet of the Apes', year=2001, score=5.7),
#               Movie(title='Batman Returns', year=1992, score=7.0),
#               Movie(title='Mars Attacks!', year=1996, score=6.3),
#               Movie(title='Big Fish', year=2003, score=8.0),
#               Movie(title='Frankenweenie', year=2012, score=7.0),
#               Movie(title='Batman', year=1989, score=7.6),
#               Movie(title='Corpse Bride', year=2005, score=7.4),
#               Movie(title='Edward Scissorhands', year=1990, score=7.9),
#               Movie(title='Ed Wood', year=1994, score=7.9),
#               Movie(title='Beetlejuice', year=1988, score=7.5),
#               Movie(title='Big Eyes', year=2014, score=7.0),
#               Movie(title='Planet of the Apes', year=2001, score=5.7),
#               Movie(title='Alice in Wonderland', year=2010, score=6.5)],
#              'Brett Ratner': [Movie(title='X-Men: The Last Stand', year=2006, score=6.8),
#               Movie(title='Rush Hour 3', year=2007, score=6.2),
#               Movie(title='Hercules', year=2014, score=6.0),
#               Movie(title='Rush Hour 2', year=2001, score=6.6),
#               Movie(title='Tower Heist', year=2011, score=6.2),
#               Movie(title='Red Dragon', year=2002, score=7.2),
#               Movie(title='Hercules', year=2014, score=6.0),
#               Movie(title='The Family Man', year=2000, score=6.7),
#               Movie(title='After the Sunset', year=2004, score=6.3),
#               Movie(title='Money Talks', year=1997, score=6.1)],
#              'Dan Scanlon': [Movie(title='Monsters University', year=2013, score=7.3)],
#              'Michael Bay': [Movie(title='Transformers: Revenge of the Fallen', year=2009, score=6.0),
#               Movie(title='Transformers: Age of Extinction', year=2014, score=5.7),
#               Movie(title='Transformers: Dark of the Moon', year=2011, score=6.3),
#               Movie(title='Pearl Harbor', year=2001, score=6.1),
#               Movie(title='Transformers', year=2007, score=7.1),
#               Movie(title='Armageddon', year=1998, score=6.6),
#               Movie(title='Bad Boys II', year=2003, score=6.6),
#               Movie(title='The Island', year=2005, score=6.9),
#               Movie(title='The Rock', year=1996, score=7.4),
#               Movie(title='13 Hours', year=2016, score=7.4),
#               Movie(title='Pain & Gain', year=2013, score=6.5),
#               Movie(title='Bad Boys', year=1995, score=6.8),
#               Movie(title='The Island', year=2005, score=6.9)],
#              'Joseph Kosinski': [Movie(title='TRON: Legacy', year=2010, score=6.8),
#               Movie(title='Oblivion', year=2013, score=7.0),
#               Movie(title='TRON: Legacy', year=2010, score=6.8),
#               Movie(title='Destiny', year=2014, score=8.1)],
#              'John Lasseter': [Movie(title='Cars 2', year=2011, score=6.3),
#               Movie(title='Toy Story 2', year=1999, score=7.9),
#               Movie(title='Cars', year=2006, score=7.2),
#               Movie(title="A Bug's Life", year=1998, score=7.2),
#               Movie(title='Toy Story', year=1995, score=8.3)],
#              'Martin Campbell': [Movie(title='Green Lantern', year=2011, score=5.6),
#               Movie(title='Casino Royale', year=2006, score=8.0),
#               Movie(title='The Legend of Zorro', year=2005, score=5.9),
#               Movie(title='Vertical Limit', year=2000, score=5.9),
#               Movie(title='The Mask of Zorro', year=1998, score=6.7),
#               Movie(title='GoldenEye', year=1995, score=7.2),
#               Movie(title='Edge of Darkness', year=2010, score=6.6),
#               Movie(title='Beyond Borders', year=2003, score=6.5),
#               Movie(title='Casino Royale', year=2006, score=8.0)],
#              'Lee Unkrich': [Movie(title='Toy Story 3', year=2010, score=8.3)],
#              'McG': [Movie(title='Terminator Salvation', year=2009, score=6.6),
#               Movie(title="Charlie's Angels: Full Throttle", year=2003, score=4.8),
#               Movie(title="Charlie's Angels", year=2000, score=5.5),
#               Movie(title='This Means War', year=2012, score=6.3),
#               Movie(title='We Are Marshall', year=2006, score=7.1),
#               Movie(title='3 Days to Kill', year=2014, score=6.2)],
#              'James Wan': [Movie(title='Furious 7', year=2015, score=7.2),
#               Movie(title='The Conjuring 2', year=2016, score=7.8),
#               Movie(title='The Conjuring', year=2013, score=7.5),
#               Movie(title='Death Sentence', year=2007, score=6.8),
#               Movie(title='Insidious: Chapter 2', year=2013, score=6.6),
#               Movie(title='Insidious', year=2010, score=6.8),
#               Movie(title='Saw', year=2004, score=7.7)],
#              'J.J. Abrams': [Movie(title='Star Trek Into Darkness', year=2013, score=7.8),
#               Movie(title='Mission: Impossible III', year=2006, score=6.9),
#               Movie(title='Star Trek', year=2009, score=8.0),
#               Movie(title='Super 8', year=2011, score=7.1)],
#              'Baz Luhrmann': [Movie(title='The Great Gatsby', year=2013, score=7.3),
#               Movie(title='Australia', year=2008, score=6.6),
#               Movie(title='Moulin Rouge!', year=2001, score=7.6),
#               Movie(title='Romeo + Juliet', year=1996, score=6.8),
#               Movie(title='The Great Gatsby', year=2013, score=7.3)],
#              'Mike Newell': [Movie(title='Prince of Persia: The Sands of Time', year=2010, score=6.6),
#               Movie(title='Harry Potter and the Goblet of Fire', year=2005, score=7.6),
#               Movie(title='Mona Lisa Smile', year=2003, score=6.4),
#               Movie(title='Love in the Time of Cholera', year=2007, score=6.4),
#               Movie(title='Donnie Brasco', year=1997, score=7.8),
#               Movie(title='Pushing Tin', year=1999, score=6.0),
#               Movie(title='Four Weddings and a Funeral', year=1994, score=7.1)],
#              'Guillermo del Toro': [Movie(title='Pacific Rim', year=2013, score=7.0),
#               Movie(title='Hellboy II: The Golden Army', year=2008, score=7.0),
#               Movie(title='Hellboy', year=2004, score=6.8),
#               Movie(title='Blade II', year=2002, score=6.7),
#               Movie(title="Pan's Labyrinth", year=2006, score=8.2)],
#              'Steven Spielberg': [Movie(title='Indiana Jones and the Kingdom of the Crystal Skull', year=2008, score=6.2),
#               Movie(title='The BFG', year=2016, score=6.8),
#               Movie(title='War of the Worlds', year=2005, score=6.5),
#               Movie(title='The Adventures of Tintin', year=2011, score=7.4),
#               Movie(title='Minority Report', year=2002, score=7.7),
#               Movie(title='A.I. Artificial Intelligence', year=2001, score=7.1),
#               Movie(title='The Lost World: Jurassic Park', year=1997, score=6.5),
#               Movie(title='The Terminal', year=2004, score=7.3),
#               Movie(title='Munich', year=2005, score=7.6),
#               Movie(title='Hook', year=1991, score=6.7),
#               Movie(title='War Horse', year=2011, score=7.2),
#               Movie(title='Saving Private Ryan', year=1998, score=8.6),
#               Movie(title='Lincoln', year=2012, score=7.4),
#               Movie(title='Jurassic Park', year=1993, score=8.1),
#               Movie(title='Catch Me If You Can', year=2002, score=8.0),
#               Movie(title='Indiana Jones and the Last Crusade', year=1989, score=8.3),
#               Movie(title='Bridge of Spies', year=2015, score=7.6),
#               Movie(title='Amistad', year=1997, score=7.2),
#               Movie(title='1941', year=1979, score=5.9),
#               Movie(title='Indiana Jones and the Temple of Doom', year=1984, score=7.6),
#               Movie(title="Schindler's List", year=1993, score=8.9),
#               Movie(title='Raiders of the Lost Ark', year=1981, score=8.5),
#               Movie(title='Close Encounters of the Third Kind', year=1977, score=7.7),
#               Movie(title='The Color Purple', year=1985, score=7.8),
#               Movie(title='Jaws', year=1975, score=8.0),
#               Movie(title='E.T. the Extra-Terrestrial', year=1982, score=7.9)],
#              'Peter Sohn': [Movie(title='The Good Dinosaur', year=2015, score=6.8)],
#              'Mark Andrews': [Movie(title='Brave', year=2012, score=7.2)],
#              'Justin Lin': [Movie(title='Star Trek Beyond', year=2016, score=7.5),
#               Movie(title='Fast Five', year=2011, score=7.3),
#               Movie(title='The Fast and the Furious: Tokyo Drift', year=2006, score=6.0),
#               Movie(title='Finishing the Game: The Search for a New Bruce Lee', year=2007, score=6.2),
#               Movie(title='Better Luck Tomorrow', year=2002, score=7.2)],
#              'Roland Emmerich': [Movie(title='2012', year=2009, score=5.8),
#               Movie(title='Independence Day: Resurgence', year=2016, score=5.5),
#               Movie(title='White House Down', year=2013, score=6.4),
#               Movie(title='The Day After Tomorrow', year=2004, score=6.4),
#               Movie(title='The Patriot', year=2000, score=7.1),
#               Movie(title='Independence Day', year=1996, score=6.9),
#               Movie(title='Anonymous', year=2011, score=6.9),
#               Movie(title='Stonewall', year=2015, score=4.5)],
#              'Robert Zemeckis': [Movie(title='A Christmas Carol', year=2009, score=6.8),
#               Movie(title='The Polar Express', year=2004, score=6.6),
#               Movie(title='Beowulf', year=2007, score=6.3),
#               Movie(title='What Lies Beneath', year=2000, score=6.6),
#               Movie(title='Contact', year=1997, score=7.4),
#               Movie(title='Cast Away', year=2000, score=7.7),
#               Movie(title='Forrest Gump', year=1994, score=8.8),
#               Movie(title='Death Becomes Her', year=1992, score=6.4),
#               Movie(title='Back to the Future Part II', year=1989, score=7.8),
#               Movie(title='Back to the Future Part III', year=1990, score=7.4),
#               Movie(title='The Walk', year=2015, score=7.4),
#               Movie(title='Flight', year=2012, score=7.3),
#               Movie(title='Back to the Future', year=1985, score=8.5)],
#              'Lana Wachowski': [Movie(title='Jupiter Ascending', year=2015, score=5.4),
#               Movie(title='The Matrix Revolutions', year=2003, score=6.7),
#               Movie(title='The Matrix Reloaded', year=2003, score=7.2),
#               Movie(title='Speed Racer', year=2008, score=6.1),
#               Movie(title='The Matrix', year=1999, score=8.7),
#               Movie(title='Bound', year=1996, score=7.4)],
#              'Pete Docter': [Movie(title='Up', year=2009, score=8.3),
#               Movie(title='Inside Out', year=2015, score=8.3),
#               Movie(title='Monsters, Inc.', year=2001, score=8.1)],
#              'Rob Letterman': [Movie(title='Monsters vs. Aliens', year=2009, score=6.5),
#               Movie(title="Gulliver's Travels", year=2010, score=4.9),
#               Movie(title='Goosebumps', year=2015, score=6.4),
#               Movie(title='Goosebumps', year=2015, score=6.4)],
#              'Jon Favreau': [Movie(title='Iron Man', year=2008, score=7.9),
#               Movie(title='The Jungle Book', year=2016, score=7.8),
#               Movie(title='Iron Man 2', year=2010, score=7.0),
#               Movie(title='Zathura: A Space Adventure', year=2005, score=6.1),
#               Movie(title='Elf', year=2003, score=6.9),
#               Movie(title='The Jungle Book', year=2016, score=7.8),
#               Movie(title='Made', year=2001, score=6.4)],
#              'Martin Scorsese': [Movie(title='Hugo', year=2011, score=7.5),
#               Movie(title='The Aviator', year=2004, score=7.5),
#               Movie(title='The Wolf of Wall Street', year=2013, score=8.2),
#               Movie(title='Gangs of New York', year=2002, score=7.5),
#               Movie(title='The Departed', year=2006, score=8.5),
#               Movie(title='Shutter Island', year=2010, score=8.1),
#               Movie(title='Casino', year=1995, score=8.2),
#               Movie(title='Mean Streets', year=1973, score=7.4),
#               Movie(title='Cape Fear', year=1991, score=7.3),
#               Movie(title='The Age of Innocence', year=1993, score=7.2),
#               Movie(title='Bringing Out the Dead', year=1999, score=6.8),
#               Movie(title='Kundun', year=1997, score=7.0),
#               Movie(title='Goodfellas', year=1990, score=8.7),
#               Movie(title='Raging Bull', year=1980, score=8.3),
#               Movie(title='New York, New York', year=1977, score=6.7),
#               Movie(title='The Color of Money', year=1986, score=7.0),
#               Movie(title='The Last Temptation of Christ', year=1988, score=7.6),
#               Movie(title='Taxi Driver', year=1976, score=8.3),
#               Movie(title='Shine a Light', year=2008, score=7.2),
#               Movie(title='The Last Waltz', year=1978, score=8.2)],
#              'Rob Cohen': [Movie(title='The Mummy: Tomb of the Dragon Emperor', year=2008, score=5.2),
#               Movie(title='The Fast and the Furious', year=2001, score=6.7),
#               Movie(title='Stealth', year=2005, score=5.0),
#               Movie(title='The Fast and the Furious', year=2001, score=6.7),
#               Movie(title='Daylight', year=1996, score=5.8),
#               Movie(title='xXx', year=2002, score=5.8),
#               Movie(title='DragonHeart', year=1996, score=6.4),
#               Movie(title='The Fast and the Furious', year=2001, score=6.7),
#               Movie(title='Alex Cross', year=2012, score=5.1),
#               Movie(title='The Skulls', year=2000, score=5.6),
#               Movie(title='The Boy Next Door', year=2015, score=4.6)],
#              'David Ayer': [Movie(title='Suicide Squad', year=2016, score=6.9),
#               Movie(title='Fury', year=2014, score=7.6),
#               Movie(title='Sabotage', year=2014, score=5.7),
#               Movie(title='Street Kings', year=2008, score=6.8),
#               Movie(title='End of Watch', year=2012, score=7.7),
#               Movie(title='Harsh Times', year=2005, score=7.0),
#               Movie(title='Sabotage', year=2014, score=5.7)],
#              'Tom Shadyac': [Movie(title='Evan Almighty', year=2007, score=5.4),
#               Movie(title='Bruce Almighty', year=2003, score=6.7),
#               Movie(title='Dragonfly', year=2002, score=6.1),
#               Movie(title='The Nutty Professor', year=1996, score=5.6),
#               Movie(title='Patch Adams', year=1998, score=6.7),
#               Movie(title='Liar Liar', year=1997, score=6.8),
#               Movie(title='Ace Ventura: Pet Detective', year=1994, score=6.9)],
#              'Doug Liman': [Movie(title='Edge of Tomorrow', year=2014, score=7.9),
#               Movie(title='Mr. & Mrs. Smith', year=2005, score=6.5),
#               Movie(title='Jumper', year=2008, score=6.1),
#               Movie(title='The Bourne Identity', year=2002, score=7.9),
#               Movie(title='Fair Game', year=2010, score=6.8),
#               Movie(title='Go', year=1999, score=7.3),
#               Movie(title='Swingers', year=1996, score=7.4)],
#              'Kevin Reynolds': [Movie(title='Waterworld', year=1995, score=6.1),
#               Movie(title='Robin Hood: Prince of Thieves', year=1991, score=6.9),
#               Movie(title='The Count of Monte Cristo', year=2002, score=7.7),
#               Movie(title='Risen', year=2016, score=6.3),
#               Movie(title='Rapa Nui', year=1994, score=6.4)],
#              'Stephen Sommers': [Movie(title='G.I. Joe: The Rise of Cobra', year=2009, score=5.8),
#               Movie(title='The Mummy Returns', year=2001, score=6.3),
#               Movie(title='Deep Rising', year=1998, score=6.0),
#               Movie(title='The Adventures of Huck Finn', year=1993, score=6.2)],
#              'Rupert Sanders': [Movie(title='Snow White and the Huntsman', year=2012, score=6.1)],
#              'Robert Stromberg': [Movie(title='Maleficent', year=2014, score=7.0)],
#              'Matt Reeves': [Movie(title='Dawn of the Planet of the Apes', year=2014, score=7.6),
#               Movie(title='Cloverfield', year=2008, score=7.0),
#               Movie(title='Let Me In', year=2010, score=7.2),
#               Movie(title='The Pallbearer', year=1996, score=4.9)],
#              'Roland Joffé': [Movie(title='The Lovers', year=2015, score=4.5),
#               Movie(title='The Scarlet Letter', year=1995, score=5.1),
#               Movie(title='There Be Dragons', year=2011, score=5.9),
#               Movie(title='The Lovers', year=2015, score=4.5)],
#              'Carl Rinsch': [Movie(title='47 Ronin', year=2013, score=6.3)],
#              'Mike Mitchell': [Movie(title='Shrek Forever After', year=2010, score=6.4),
#               Movie(title='Alvin and the Chipmunks: Chipwrecked', year=2011, score=4.4),
#               Movie(title='Sky High', year=2005, score=6.2),
#               Movie(title='Deuce Bigalow: Male Gigolo', year=1999, score=5.7)],
#              'Brad Bird': [Movie(title='Tomorrowland', year=2015, score=6.5),
#               Movie(title='Ratatouille', year=2007, score=8.0),
#               Movie(title='Mission: Impossible - Ghost Protocol', year=2011, score=7.4),
#               Movie(title='The Incredibles', year=2004, score=8.0),
#               Movie(title='The Iron Giant', year=1999, score=8.0)],
#              'Don Hall': [Movie(title='Big Hero 6', year=2014, score=7.9)],
#              'Rich Moore': [Movie(title='Wreck-It Ralph', year=2012, score=7.8)],
#              'Dean DeBlois': [Movie(title='How to Train Your Dragon', year=2010, score=8.2),
#               Movie(title='How to Train Your Dragon 2', year=2014, score=7.9),
#               Movie(title='Lilo & Stitch', year=2002, score=7.2)],
#              'Jonathan Mostow': [Movie(title='Terminator 3: Rise of the Machines', year=2003, score=6.4),
#               Movie(title='Surrogates', year=2009, score=6.3),
#               Movie(title='U-571', year=2000, score=6.6),
#               Movie(title='Breakdown', year=1997, score=6.9)],
#              'James Gunn': [Movie(title='Guardians of the Galaxy', year=2014, score=8.1),
#               Movie(title='Slither', year=2006, score=6.5),
#               Movie(title='Super', year=2010, score=6.8)],
#              'Hideaki Anno': [Movie(title='Godzilla Resurgence', year=2016, score=8.2),
#               Movie(title='Godzilla Resurgence', year=2016, score=8.2)],
#              'David Fincher': [Movie(title='The Curious Case of Benjamin Button', year=2008, score=7.8),
#               Movie(title='The Girl with the Dragon Tattoo', year=2011, score=7.8),
#               Movie(title='Zodiac', year=2007, score=7.7),
#               Movie(title='Fight Club', year=1999, score=8.8),
#               Movie(title='Gone Girl', year=2014, score=8.1),
#               Movie(title='Alien 3', year=1992, score=6.4),
#               Movie(title='The Game', year=1997, score=7.8),
#               Movie(title='Panic Room', year=2002, score=6.8),
#               Movie(title='The Social Network', year=2010, score=7.7),
#               Movie(title='Se7en', year=1995, score=8.6)],
#              'Matthew Vaughn': [Movie(title='X-Men: First Class', year=2011, score=7.8),
#               Movie(title='Stardust', year=2007, score=7.7),
#               Movie(title='Kick-Ass', year=2010, score=7.7),
#               Movie(title='Layer Cake', year=2004, score=7.4)],
#              'Francis Lawrence': [Movie(title='The Hunger Games: Mockingjay - Part 2', year=2015, score=6.6),
#               Movie(title='I Am Legend', year=2007, score=7.2),
#               Movie(title='The Hunger Games: Catching Fire', year=2013, score=7.6),
#               Movie(title='The Hunger Games: Mockingjay - Part 1', year=2014, score=6.7),
#               Movie(title='Water for Elephants', year=2011, score=6.9)],
#              'Jon Turteltaub': [Movie(title="The Sorcerer's Apprentice", year=2010, score=6.1),
#               Movie(title='National Treasure', year=2004, score=6.9),
#               Movie(title='The Kid', year=2000, score=6.1),
#               Movie(title='Instinct', year=1999, score=6.5),
#               Movie(title='Phenomenon', year=1996, score=6.4),
#               Movie(title='Last Vegas', year=2013, score=6.6),
#               Movie(title='Cool Runnings', year=1993, score=6.9)],
#              'Wolfgang Petersen': [Movie(title='Poseidon', year=2006, score=5.6),
#               Movie(title='Troy', year=2004, score=7.2),
#               Movie(title='The Perfect Storm', year=2000, score=6.4),
#               Movie(title='Air Force One', year=1997, score=6.4),
#               Movie(title='Outbreak', year=1995, score=6.6),
#               Movie(title='The NeverEnding Story', year=1984, score=7.4),
#               Movie(title='Das Boot', year=1981, score=8.4)],
#              'James Bobin': [Movie(title='Alice Through the Looking Glass', year=2016, score=6.4),
#               Movie(title='Muppets Most Wanted', year=2014, score=6.4),
#               Movie(title='The Muppets', year=2011, score=7.1)],
#              'Chris Miller': [Movie(title='Shrek the Third', year=2007, score=6.1),
#               Movie(title='Puss in Boots', year=2011, score=6.7)],
#              'Duncan Jones': [Movie(title='Warcraft', year=2016, score=7.3),
#               Movie(title='Source Code', year=2011, score=7.5),
#               Movie(title='Moon', year=2009, score=7.9)],
#              'Alan Taylor': [Movie(title='Terminator Genisys', year=2015, score=6.6),
#               Movie(title='Thor: The Dark World', year=2013, score=7.1)],
#              'Michael Apted': [Movie(title='The Chronicles of Narnia: The Voyage of the Dawn Treader', year=2010, score=6.3),
#               Movie(title='The World Is Not Enough', year=1999, score=6.4),
#               Movie(title='Enough', year=2002, score=5.6),
#               Movie(title='Extreme Measures', year=1996, score=6.1),
#               Movie(title='Chasing Mavericks', year=2012, score=7.2),
#               Movie(title="Coal Miner's Daughter", year=1980, score=7.5)],
#              'Oliver Stone': [Movie(title='Alexander', year=2004, score=5.5),
#               Movie(title='Wall Street: Money Never Sleeps', year=2010, score=6.3),
#               Movie(title='World Trade Center', year=2006, score=6.0),
#               Movie(title='Any Given Sunday', year=1999, score=6.8),
#               Movie(title='Savages', year=2012, score=6.5),
#               Movie(title='Nixon', year=1995, score=7.1),
#               Movie(title='JFK', year=1991, score=8.0),
#               Movie(title='The Doors', year=1991, score=7.2),
#               Movie(title='W.', year=2008, score=6.4),
#               Movie(title='Wall Street', year=1987, score=7.4),
#               Movie(title='Born on the Fourth of July', year=1989, score=7.2),
#               Movie(title='Platoon', year=1986, score=8.1),
#               Movie(title='Salvador', year=1986, score=7.5),
#               Movie(title='Talk Radio', year=1988, score=7.3)],
#              'Eric Darnell': [Movie(title='Madagascar: Escape 2 Africa', year=2008, score=6.7),
#               Movie(title="Madagascar 3: Europe's Most Wanted", year=2012, score=6.9),
#               Movie(title='Penguins of Madagascar', year=2014, score=6.7),
#               Movie(title='Madagascar', year=2005, score=6.9),
#               Movie(title='Antz', year=1998, score=6.6)],
#              'Shawn Levy': [Movie(title='Night at the Museum: Battle of the Smithsonian', year=2009, score=5.9),
#               Movie(title='Night at the Museum: Secret of the Tomb', year=2014, score=6.2),
#               Movie(title='Night at the Museum', year=2006, score=6.4),
#               Movie(title='Real Steel', year=2011, score=7.1),
#               Movie(title='The Pink Panther', year=2006, score=5.6),
#               Movie(title='The Internship', year=2013, score=6.3),
#               Movie(title='Date Night', year=2010, score=6.3),
#               Movie(title='Cheaper by the Dozen', year=2003, score=5.8),
#               Movie(title='This Is Where I Leave You', year=2014, score=6.6),
#               Movie(title='Just Married', year=2003, score=5.4),
#               Movie(title='Big Fat Liar', year=2002, score=5.4),
#               Movie(title='Big Fat Liar', year=2002, score=5.4)],
#              'Gavin Hood': [Movie(title='X-Men Origins: Wolverine', year=2009, score=6.7),
#               Movie(title="Ender's Game", year=2013, score=6.7),
#               Movie(title='Rendition', year=2007, score=6.8),
#               Movie(title='Tsotsi', year=2005, score=7.3)],
#              'Chris Buck': [Movie(title='Frozen', year=2013, score=7.6)],
#              'George Miller': [Movie(title='Mad Max: Fury Road', year=2015, score=8.1),
#               Movie(title='Happy Feet 2', year=2011, score=5.9),
#               Movie(title='Happy Feet', year=2006, score=6.5),
#               Movie(title='Babe: Pig in the City', year=1998, score=5.8),
#               Movie(title='Mad Max Beyond Thunderdome', year=1985, score=6.2),
#               Movie(title='The Man from Snowy River', year=1982, score=7.3),
#               Movie(title='Mad Max 2: The Road Warrior', year=1981, score=7.6),
#               Movie(title='Mad Max', year=1979, score=7.0)],
#              'Ron Howard': [Movie(title='Angels & Demons', year=2009, score=6.7),
#               Movie(title='The Da Vinci Code', year=2006, score=6.6),
#               Movie(title='How the Grinch Stole Christmas', year=2000, score=6.0),
#               Movie(title='In the Heart of the Sea', year=2015, score=7.0),
#               Movie(title='Cinderella Man', year=2005, score=8.0),
#               Movie(title='A Beautiful Mind', year=2001, score=8.2),
#               Movie(title='Ransom', year=1996, score=6.6),
#               Movie(title='The Dilemma', year=2011, score=5.3),
#               Movie(title='Apollo 13', year=1995, score=7.6),
#               Movie(title='Edtv', year=1999, score=6.1),
#               Movie(title='Rush', year=2013, score=8.1),
#               Movie(title='Frost/Nixon', year=2008, score=7.7),
#               Movie(title='Splash', year=1984, score=6.2)],
#              'Kenneth Branagh': [Movie(title='Thor', year=2011, score=7.0),
#               Movie(title='Cinderella', year=2015, score=7.0),
#               Movie(title='Jack Ryan: Shadow Recruit', year=2014, score=6.2),
#               Movie(title='The Magic Flute', year=2006, score=6.6),
#               Movie(title='Hamlet', year=1996, score=7.8),
#               Movie(title='Henry V', year=1989, score=7.7),
#               Movie(title='Much Ado About Nothing', year=1993, score=7.4),
#               Movie(title='Cinderella', year=2015, score=7.0),
#               Movie(title='Hamlet', year=1996, score=7.8)],
#              'Byron Howard': [Movie(title='Bolt', year=2008, score=6.9)],
#              'Hoyt Yeatman': [Movie(title='G-Force', year=2009, score=5.1)],
#              'Jonathan Liebesman': [Movie(title='Wrath of the Titans', year=2012, score=5.8),
#               Movie(title='Teenage Mutant Ninja Turtles', year=2014, score=5.9),
#               Movie(title='Battle Los Angeles', year=2011, score=5.8),
#               Movie(title='The Texas Chainsaw Massacre: The Beginning', year=2006, score=5.9),
#               Movie(title='Teenage Mutant Ninja Turtles', year=2014, score=5.9),
#               Movie(title='Darkness Falls', year=2003, score=4.9)],
#              'Christopher McQuarrie': [Movie(title='Mission: Impossible - Rogue Nation', year=2015, score=7.4),
#               Movie(title='Jack Reacher', year=2012, score=7.0),
#               Movie(title='The Way of the Gun', year=2000, score=6.7),
#               Movie(title='Jack Reacher', year=2012, score=7.0)],
#              'Joe Johnston': [Movie(title='The Wolfman', year=2010, score=5.8),
#               Movie(title='Captain America: The First Avenger', year=2011, score=6.9),
#               Movie(title='Jurassic Park III', year=2001, score=5.9),
#               Movie(title='Hidalgo', year=2004, score=6.7)],
#              'Steve Hickner': [Movie(title='Bee Movie', year=2007, score=6.2)],
#              'Jennifer Yuh Nelson': [Movie(title='Kung Fu Panda 2', year=2011, score=7.3)],
#              'M. Night Shyamalan': [Movie(title='The Last Airbender', year=2010, score=4.2),
#               Movie(title='After Earth', year=2013, score=4.9),
#               Movie(title='Unbreakable', year=2000, score=7.2),
#               Movie(title='The Village', year=2004, score=6.5),
#               Movie(title='Signs', year=2002, score=6.7),
#               Movie(title='Lady in the Water', year=2006, score=5.6),
#               Movie(title='The Happening', year=2008, score=5.0),
#               Movie(title='The Sixth Sense', year=1999, score=8.1),
#               Movie(title='The Visit', year=2015, score=6.2)],
#              'Simon Wells': [Movie(title='Mars Needs Moms', year=2011, score=5.4),
#               Movie(title='The Time Machine', year=2002, score=5.9)],
#              'David Bowers': [Movie(title='Flushed Away', year=2006, score=6.7),
#               Movie(title='Astro Boy', year=2009, score=6.3),
#               Movie(title='Diary of a Wimpy Kid: Dog Days', year=2012, score=6.4),
#               Movie(title='Diary of a Wimpy Kid: Rodrick Rules', year=2011, score=6.6)],
#              'Joe Wright': [Movie(title='Pan', year=2015, score=5.8),
#               Movie(title='Pan', year=2015, score=5.8),
#               Movie(title='The Soloist', year=2009, score=6.7),
#               Movie(title='Anna Karenina', year=2012, score=6.6),
#               Movie(title='Atonement', year=2007, score=7.8),
#               Movie(title='Hanna', year=2011, score=6.8),
#               Movie(title='Pride & Prejudice', year=2005, score=7.8),
#               Movie(title='Pan', year=2015, score=5.8)],
#              'Rob Minkoff': [Movie(title='Mr. Peabody & Sherman', year=2014, score=6.9),
#               Movie(title='Stuart Little 2', year=2002, score=5.4),
#               Movie(title='Stuart Little', year=1999, score=5.9),
#               Movie(title='The Haunted Mansion', year=2003, score=4.9),
#               Movie(title='The Forbidden Kingdom', year=2008, score=6.6)],
#              'Lee Tamahori': [Movie(title='Die Another Day', year=2002, score=6.1),
#               Movie(title='The Edge', year=1997, score=6.9),
#               Movie(title='xXx: State of the Union', year=2005, score=4.3),
#               Movie(title='Along Came a Spider', year=2001, score=6.3),
#               Movie(title="The Devil's Double", year=2011, score=7.1)],
#              'Paul Feig': [Movie(title='Ghostbusters', year=2016, score=5.5),
#               Movie(title='The Heat', year=2013, score=6.6),
#               Movie(title='Bridesmaids', year=2011, score=6.8),
#               Movie(title='Ghostbusters', year=2016, score=5.5),
#               Movie(title='Unaccompanied Minors', year=2006, score=5.1)],
#              'Alessandro Carloni': [Movie(title='Kung Fu Panda 3', year=2016, score=7.2)],
#              'Peter Ramsey': [Movie(title='Rise of the Guardians', year=2012, score=7.3)],
#              'Dean Parisot': [Movie(title='Fun with Dick and Jane', year=2005, score=6.1),
#               Movie(title='RED 2', year=2013, score=6.7),
#               Movie(title='Galaxy Quest', year=1999, score=7.3),
#               Movie(title='Home Fries', year=1998, score=5.0)],
#              'Edward Zwick': [Movie(title='The Last Samurai', year=2003, score=7.7),
#               Movie(title='Blood Diamond', year=2006, score=8.0),
#               Movie(title='The Siege', year=1998, score=6.3),
#               Movie(title='Courage Under Fire', year=1996, score=6.6),
#               Movie(title='Legends of the Fall', year=1994, score=7.5),
#               Movie(title='Love & Other Drugs', year=2010, score=6.7),
#               Movie(title='Glory', year=1989, score=7.9),
#               Movie(title='Glory', year=1989, score=7.9)],
#              'Alex Proyas': [Movie(title='Gods of Egypt', year=2016, score=5.5),
#               Movie(title='I, Robot', year=2004, score=7.1),
#               Movie(title='Knowing', year=2009, score=6.2),
#               Movie(title='The Crow', year=1994, score=7.6),
#               Movie(title='Dark City', year=1998, score=7.7)],
#              'Richard Donner': [Movie(title='Lethal Weapon 4', year=1998, score=6.6),
#               Movie(title='Conspiracy Theory', year=1997, score=6.7),
#               Movie(title='Timeline', year=2003, score=5.6),
#               Movie(title='Superman', year=1978, score=7.3),
#               Movie(title='Assassins', year=1995, score=6.3),
#               Movie(title='16 Blocks', year=2006, score=6.6),
#               Movie(title='Lethal Weapon 3', year=1992, score=6.7),
#               Movie(title='Radio Flyer', year=1992, score=6.9),
#               Movie(title='Scrooged', year=1988, score=7.0),
#               Movie(title='The Omen', year=1976, score=7.6),
#               Movie(title='Ladyhawke', year=1985, score=7.0),
#               Movie(title='The Omen', year=1976, score=7.6)],
#              'Ang Lee': [Movie(title='Hulk', year=2003, score=5.7),
#               Movie(title='Life of Pi', year=2012, score=8.0),
#               Movie(title='Ride with the Devil', year=1999, score=6.8),
#               Movie(title='Taking Woodstock', year=2009, score=6.7),
#               Movie(title='The Ice Storm', year=1997, score=7.5),
#               Movie(title='Sense and Sensibility', year=1995, score=7.7),
#               Movie(title='Crouching Tiger, Hidden Dragon', year=2000, score=7.9),
#               Movie(title='Brokeback Mountain', year=2005, score=7.7)],
#              'Jon M. Chu': [Movie(title='G.I. Joe: Retaliation', year=2013, score=5.8),
#               Movie(title='Now You See Me 2', year=2016, score=6.9),
#               Movie(title='Step Up 3D', year=2010, score=6.2),
#               Movie(title='Step Up 2: The Streets', year=2008, score=6.2),
#               Movie(title='Justin Bieber: Never Say Never', year=2011, score=1.6)],
#              'Breck Eisner': [Movie(title='Sahara', year=2005, score=6.0),
#               Movie(title='The Last Witch Hunter', year=2015, score=6.0),
#               Movie(title='The Crazies', year=2010, score=6.5)],
#              'Hironobu Sakaguchi': [Movie(title='Final Fantasy: The Spirits Within', year=2001, score=6.4)],
#              'Peter Weir': [Movie(title='Master and Commander: The Far Side of the World', year=2003, score=7.4),
#               Movie(title='The Truman Show', year=1998, score=8.1),
#               Movie(title='Dead Poets Society', year=1989, score=8.0),
#               Movie(title='Witness', year=1985, score=7.4)],
#              'Bill Condon': [Movie(title='The Twilight Saga: Breaking Dawn - Part 2', year=2012, score=5.5),
#               Movie(title='The Twilight Saga: Breaking Dawn - Part 2', year=2012, score=5.5),
#               Movie(title='Dreamgirls', year=2006, score=6.5),
#               Movie(title='The Fifth Estate', year=2013, score=6.2),
#               Movie(title='Kinsey', year=2004, score=7.1),
#               Movie(title='Gods and Monsters', year=1998, score=7.5)],
#              'Louis Leterrier': [Movie(title='The Incredible Hulk', year=2008, score=6.8),
#               Movie(title='Clash of the Titans', year=2010, score=5.8),
#               Movie(title='Now You See Me', year=2013, score=7.3),
#               Movie(title='Unleashed', year=2005, score=7.0),
#               Movie(title='Transporter 2', year=2005, score=6.3),
#               Movie(title='The Transporter', year=2002, score=6.8),
#               Movie(title='Clash of the Titans', year=2010, score=5.8)],
#              'Alejandro G. Iñárritu': [Movie(title='The Revenant', year=2015, score=8.1),
#               Movie(title='Biutiful', year=2010, score=7.5),
#               Movie(title='Babel', year=2006, score=7.5),
#               Movie(title='21 Grams', year=2003, score=7.7),
#               Movie(title='Birdman or (The Unexpected Virtue of Ignorance)', year=2014, score=7.8),
#               Movie(title='Amores Perros', year=2000, score=8.1)],
#              'David Soren': [Movie(title='Turbo', year=2013, score=6.5)],
#              'Paul Greengrass': [Movie(title='The Bourne Ultimatum', year=2007, score=8.1),
#               Movie(title='Jason Bourne', year=2016, score=7.1),
#               Movie(title='Green Zone', year=2010, score=6.9),
#               Movie(title='The Bourne Supremacy', year=2004, score=7.8),
#               Movie(title='Captain Phillips', year=2013, score=7.9),
#               Movie(title='United 93', year=2006, score=7.6),
#               Movie(title='Bloody Sunday', year=2002, score=7.7)],
#              'Mark Osborne': [Movie(title='Kung Fu Panda', year=2008, score=7.6),
#               Movie(title='The Little Prince', year=2015, score=7.8)],
#              'Peyton Reed': [Movie(title='Ant-Man', year=2015, score=7.4),
#               Movie(title='The Break-Up', year=2006, score=5.8),
#               Movie(title='Yes Man', year=2008, score=6.8),
#               Movie(title='Bring It On', year=2000, score=5.9)],
#              'Tim Johnson': [Movie(title='Home', year=2015, score=6.7),
#               Movie(title='Over the Hedge', year=2006, score=6.8),
#               Movie(title='Home', year=2015, score=6.7),
#               Movie(title='Home', year=2015, score=6.7)],
#              'Phillip Noyce': [Movie(title='Salt', year=2010, score=6.4),
#               Movie(title='The Saint', year=1997, score=6.2),
# ...
#              'Christian Carion': [Movie(title='Joyeux Noel', year=2005, score=7.8)],
#              'David Palmer': [Movie(title='Hit and Run', year=2012, score=6.1)],
#              'Rowan Joffe': [Movie(title='Before I Go to Sleep', year=2014, score=6.3),
#               Movie(title='Brighton Rock', year=2010, score=5.7)],
#              'John Curran': [Movie(title='Stone', year=2010, score=5.4),
#               Movie(title='The Painted Veil', year=2006, score=7.5)],
#              'Juan José Campanella': [Movie(title='Underdogs', year=2013, score=6.7),
#               Movie(title='The Secret in Their Eyes', year=2009, score=8.2)],
#              'Trey Parker': [Movie(title='South Park: Bigger Longer & Uncut', year=1999, score=7.8),
#               Movie(title='Team America: World Police', year=2004, score=7.2),
#               Movie(title='Orgazmo', year=1997, score=6.2)],
#              'Stuart Gillard': [Movie(title='Teenage Mutant Ninja Turtles III', year=1993, score=4.8)],
#              'Katt Shea': [Movie(title='The Rage: Carrie 2', year=1999, score=4.6)],
#              'Joshua Michael Stern': [Movie(title='Swing Vote', year=2008, score=6.1)],
#              'Tomas Alfredson': [Movie(title='Tinker Tailor Soldier Spy', year=2011, score=7.1)],
#              'John Duigan': [Movie(title='Molly', year=1999, score=5.8)],
#              'Colin Higgins': [Movie(title='The Best Little Whorehouse in Texas', year=1982, score=5.8)],
#              'Jim Sonzero': [Movie(title='Pulse', year=2006, score=4.7)],
#              'Penelope Spheeris': [Movie(title="Wayne's World", year=1992, score=7.0)],
#              'Jeff Tremaine': [Movie(title='Jackass 3D', year=2010, score=7.1),
#               Movie(title='Bad Grandpa', year=2013, score=6.6),
#               Movie(title='Jackass Number Two', year=2006, score=7.1),
#               Movie(title='Jackass: The Movie', year=2002, score=6.6)],
#              'Jeannot Szwarc': [Movie(title='Jaws 2', year=1978, score=5.7),
#               Movie(title='Somewhere in Time', year=1980, score=7.3)],
#              'Steve McQueen': [Movie(title='12 Years a Slave', year=2013, score=8.1),
#               Movie(title='Shame', year=2011, score=7.3)],
#              'Thea Sharrock': [Movie(title='Me Before You', year=2016, score=7.6)],
#              'Jon Lucas': [Movie(title='Bad Moms', year=2016, score=6.7),
#               Movie(title='Bad Moms', year=2016, score=6.7),
#               Movie(title='21 & Over', year=2013, score=5.9)],
#              'Aaron Seltzer': [Movie(title='Date Movie', year=2006, score=2.7)],
#              'Robin Budd': [Movie(title='Return to Never Land', year=2002, score=5.8)],
#              'Ava DuVernay': [Movie(title='Selma', year=2014, score=7.5),
#               Movie(title='Middle of Nowhere', year=2012, score=6.5)],
#              'Steve Trenbirth': [Movie(title='The Jungle Book 2', year=2003, score=5.4)],
#              'Mennan Yapo': [Movie(title='Premonition', year=2007, score=5.9)],
#              'Jun Falkenstein': [Movie(title='The Tigger Movie', year=2000, score=6.3)],
#              'Tom McCarthy': [Movie(title='Spotlight', year=2015, score=8.1),
#               Movie(title='The Station Agent', year=2003, score=7.7)],
#              'Takashi Shimizu': [Movie(title='The Grudge 2', year=2006, score=5.0),
#               Movie(title='The Grudge', year=2004, score=5.9)],
#              'Gary Nelson': [Movie(title='The Black Hole', year=1979, score=5.9)],
#              'Anton Corbijn': [Movie(title='The American', year=2010, score=6.3),
#               Movie(title='A Most Wanted Man', year=2014, score=6.8),
#               Movie(title='Control', year=2007, score=7.7)],
#              'Gregory Nava': [Movie(title='Selena', year=1997, score=6.7)],
#              'John Patrick Shanley': [Movie(title='Doubt', year=2008, score=7.5)],
#              'Joshua Logan': [Movie(title='Paint Your Wagon', year=1969, score=6.7)],
#              'Steve Beck': [Movie(title='Ghost Ship', year=2002, score=5.5),
#               Movie(title='Thir13en Ghosts', year=2001, score=5.5)],
#              'Todd Strauss-Schulson': [Movie(title='A Very Harold & Kumar 3D Christmas', year=2011, score=6.3)],
#              'John McNaughton': [Movie(title='Wild Things', year=1998, score=6.5)],
#              'Nelson McCormick': [Movie(title='The Stepfather', year=2009, score=5.6),
#               Movie(title='Prom Night', year=2008, score=3.9)],
#              'Eric Valette': [Movie(title='One Missed Call', year=2008, score=3.9),
#               Movie(title='Super Hybrid', year=2010, score=3.9)],
#              'Andrew Fleming': [Movie(title='Nancy Drew', year=2007, score=5.9),
#               Movie(title='The Craft', year=1996, score=6.2),
#               Movie(title='Dick', year=1999, score=6.1),
#               Movie(title='Hamlet 2', year=2008, score=6.4)],
#              'Michael Spierig': [Movie(title='Daybreakers', year=2009, score=6.5)],
#              'Jim Field Smith': [Movie(title="She's Out of My League", year=2010, score=6.4)],
#              'Thomas Bezucha': [Movie(title='Monte Carlo', year=2011, score=5.8),
#               Movie(title='The Family Stone', year=2005, score=6.3)],
#              'William Brent Bell': [Movie(title='Stay Alive', year=2006, score=5.1),
#               Movie(title='The Boy', year=2016, score=6.0),
#               Movie(title='The Devil Inside', year=2012, score=4.2)],
#              'Anthony Bell': [Movie(title='Alpha and Omega', year=2010, score=5.3)],
#              'Jessica Bendinger': [Movie(title='Stick It', year=2006, score=6.4)],
#              'Henry Joost': [Movie(title='Nerve', year=2016, score=7.1),
#               Movie(title='Paranormal Activity 3', year=2011, score=5.8),
#               Movie(title='Paranormal Activity 4', year=2012, score=4.6)],
#              'Ed Harris': [Movie(title='Appaloosa', year=2008, score=6.8),
#               Movie(title='Pollock', year=2000, score=7.0)],
#              'Alfred Hitchcock': [Movie(title='Psycho', year=1960, score=8.5),
#               Movie(title='Topaz', year=1969, score=6.3),
#               Movie(title='Frenzy', year=1972, score=7.5),
#               Movie(title='Family Plot', year=1976, score=6.8),
#               Movie(title='Torn Curtain', year=1966, score=6.7),
#               Movie(title='Spellbound', year=1945, score=7.6),
#               Movie(title='Rebecca', year=1940, score=8.2),
#               Movie(title='The Trouble with Harry', year=1955, score=7.2)],
#              'Shana Feste': [Movie(title='Endless Love', year=2014, score=6.3),
#               Movie(title='Country Strong', year=2010, score=6.3),
#               Movie(title='The Greatest', year=2009, score=6.7)],
#              'Steve Rash': [Movie(title='Under the Rainbow', year=1981, score=5.4),
#               Movie(title='Held Up', year=1999, score=5.1)],
#              'Mike Binder': [Movie(title='Reign Over Me', year=2007, score=7.5),
#               Movie(title='The Upside of Anger', year=2005, score=6.9),
#               Movie(title='Black or White', year=2014, score=6.6)],
#              'Michael J. Bassett': [Movie(title='Silent Hill: Revelation 3D', year=2012, score=5.0)],
#              'Frank Nissen': [Movie(title="Pooh's Heffalump Movie", year=2005, score=6.4)],
#              'Stephen Chow': [Movie(title='Kung Fu Hustle', year=2004, score=7.8),
#               Movie(title='CJ7', year=2008, score=6.5),
#               Movie(title='Shaolin Soccer', year=2001, score=7.3)],
#              'Peter Hastings': [Movie(title='The Country Bears', year=2002, score=4.0)],
#              'Paul Abascal': [Movie(title='Paparazzi', year=2004, score=5.8)],
#              'Chris Koch': [Movie(title='A Guy Thing', year=2003, score=5.6),
#               Movie(title='Snow Day', year=2000, score=4.9)],
#              'Amy Heckerling': [Movie(title='Loser', year=2000, score=5.3),
#               Movie(title='Vamps', year=2012, score=5.1),
#               Movie(title='Clueless', year=1995, score=6.8),
#               Movie(title='Fast Times at Ridgemont High', year=1982, score=7.2)],
#              'Michael Moore': [Movie(title='Capitalism: A Love Story', year=2009, score=7.4),
#               Movie(title='Sicko', year=2007, score=8.0),
#               Movie(title='Fahrenheit 9/11', year=2004, score=7.5),
#               Movie(title='Bowling for Columbine', year=2002, score=8.0),
#               Movie(title='Slacker Uprising', year=2007, score=5.3),
#               Movie(title='Roger & Me', year=1989, score=7.5)],
#              'George Stevens': [Movie(title='The Greatest Story Ever Told', year=1965, score=6.6)],
#              'Billy Ray': [Movie(title='Secret in Their Eyes', year=2015, score=6.2),
#               Movie(title='Shattered Glass', year=2003, score=7.2)],
#              'Mark Mylod': [Movie(title="What's Your Number?", year=2011, score=6.0)],
#              'James Mather': [Movie(title='Lockout', year=2012, score=6.1)],
#              'Michael O. Sajbel': [Movie(title='One Night with the King', year=2006, score=6.3),
#               Movie(title='The Ultimate Gift', year=2006, score=7.4)],
#              'Charles T. Kanganis': [Movie(title='3 Ninjas Kick Back', year=1994, score=4.3)],
#              'Damon Santostefano': [Movie(title='Three to Tango', year=1999, score=6.1)],
#              'Bob Clark': [Movie(title='Superbabies: Baby Geniuses 2', year=2004, score=1.9),
#               Movie(title='Baby Geniuses', year=1999, score=2.5),
#               Movie(title="Porky's", year=1981, score=6.2),
#               Movie(title='A Christmas Story', year=1983, score=8.1)],
#              'Dave Borthwick': [Movie(title='Doogal', year=2006, score=2.8)],
#              'Benson Lee': [Movie(title='Battle of the Year', year=2013, score=5.0)],
#              'Glen Morgan': [Movie(title='Willard', year=2003, score=6.2),
#               Movie(title='Black Christmas', year=2006, score=4.5)],
#              'Mike Leigh': [Movie(title='Topsy-Turvy', year=1999, score=7.4),
#               Movie(title='Mr. Turner', year=2014, score=6.8),
#               Movie(title='Vera Drake', year=2004, score=7.7),
#               Movie(title='All or Nothing', year=2002, score=7.6),
#               Movie(title='Another Year', year=2010, score=7.3)],
#              'Alejandro Monteverde': [Movie(title='Little Boy', year=2015, score=7.4),
#               Movie(title='Bella', year=2006, score=7.4)],
#              'Jonathan Glazer': [Movie(title='Birth', year=2004, score=6.1),
#               Movie(title='Under the Skin', year=2013, score=6.3),
#               Movie(title='Sexy Beast', year=2000, score=7.3)],
#              'J.C. Chandor': [Movie(title='A Most Violent Year', year=2014, score=7.0),
#               Movie(title='All Is Lost', year=2013, score=6.9),
#               Movie(title='Margin Call', year=2011, score=7.1)],
#              'Paul Gross': [Movie(title='Passchendaele', year=2008, score=6.5),
#               Movie(title='Men with Brooms', year=2002, score=6.0)],
#              'Marc Abraham': [Movie(title='Flash of Genius', year=2008, score=7.0)],
#              'Todd Haynes': [Movie(title="I'm Not There.", year=2007, score=7.0),
#               Movie(title='Far from Heaven', year=2002, score=7.4),
#               Movie(title='Velvet Goldmine', year=1998, score=7.0)],
#              'Mabrouk El Mechri': [Movie(title='The Cold Light of Day', year=2012, score=4.9)],
#              'Charlie Kaufman': [Movie(title='Synecdoche, New York', year=2008, score=7.5)],
#              'Nancy Walker': [Movie(title="Can't Stop the Music", year=1980, score=4.5)],
#              'Angelo Pizzo': [Movie(title='Courage', year=2015, score=7.0)],
#              'Matthew Diamond': [Movie(title='The Oogieloves in the Big Balloon Adventure', year=2012, score=6.7)],
#              'Katsuhiro Ôtomo': [Movie(title='Steamboy', year=2004, score=6.9),
#               Movie(title='Akira', year=1988, score=8.1)],
#              'David Anspaugh': [Movie(title='The Game of Their Lives', year=2005, score=6.2)],
#              'Andrew Jarecki': [Movie(title='All Good Things', year=2010, score=6.3)],
#              'Daniel Algrant': [Movie(title='People I Know', year=2002, score=5.5)],
#              'Jane Clark': [Movie(title='The Touch', year=2007, score=5.2)],
#              'Mike Barker': [Movie(title='Shattered', year=2007, score=6.7)],
#              'Wayne Thornley': [Movie(title='Zambezia', year=2012, score=5.8)],
#              'Gnana Rajasekaran': [Movie(title='Ramanujan', year=2014, score=7.0)],
#              'Tom Walsh': [Movie(title='Dwegons and Leprechauns', year=2014, score=4.8)],
#              'Jonathan Jakubowicz': [Movie(title='Hands of Stone', year=2016, score=7.2)],
#              'Scott Walker': [Movie(title='The Frozen Ground', year=2013, score=6.4)],
#              'Mark Rosman': [Movie(title='A Cinderella Story', year=2004, score=5.9),
#               Movie(title='The Perfect Man', year=2005, score=5.5)],
#              'Rob Hawk': [Movie(title='Fight Valley', year=2016, score=5.0)],
#              'Britt Allcroft': [Movie(title='Thomas and the Magic Railroad', year=2000, score=3.6)],
#              'Alan Yuen': [Movie(title='Firestorm', year=2013, score=6.2)],
#              'Brian Percival': [Movie(title='The Book Thief', year=2013, score=7.6)],
#              'Anand Tucker': [Movie(title='Leap Year', year=2010, score=6.4),
#               Movie(title='When Did You Last See Your Father?', year=2007, score=6.9),
#               Movie(title='Shopgirl', year=2005, score=6.4)],
#              'Anthony Mann': [Movie(title='The Fall of the Roman Empire', year=1964, score=6.7)],
#              'Michael Dowse': [Movie(title='Take Me Home Tonight', year=2011, score=6.3),
#               Movie(title="It's All Gone Pete Tong", year=2004, score=7.4)],
#              'Daniel Barnz': [Movie(title="Won't Back Down", year=2012, score=6.4),
#               Movie(title='Beastly', year=2011, score=5.6)],
#              'Emile Ardolino': [Movie(title='The Nutcracker', year=1993, score=5.7)],
#              'Robert Altman': [Movie(title='Kansas City', year=1996, score=6.3),
#               Movie(title='Gosford Park', year=2001, score=7.3),
#               Movie(title='A Prairie Home Companion', year=2006, score=6.8)],
#              'James Schamus': [Movie(title='Indignation', year=2016, score=7.8)],
#              'Andrew Douglas': [Movie(title='The Amityville Horror', year=2005, score=6.0)],
#              'Ricky Gervais': [Movie(title='The Invention of Lying', year=2009, score=6.4)],
#              'Vic Armstrong': [Movie(title='Left Behind', year=2014, score=3.1),
#               Movie(title='Left Behind', year=2014, score=3.1)],
#              'Terry Zwigoff': [Movie(title='Bad Santa', year=2003, score=7.1),
#               Movie(title='Ghost World', year=2001, score=7.4)],
#              'Audrey Wells': [Movie(title='Under the Tuscan Sun', year=2003, score=6.7)],
#              'Rick Friedberg': [Movie(title='Spy Hard', year=1996, score=5.3)],
#              'Sean McNamara': [Movie(title='Soul Surfer', year=2011, score=7.1),
#               Movie(title='Raise Your Voice', year=2004, score=5.9)],
#              'Jody Hill': [Movie(title='Observe and Report', year=2009, score=5.8)],
#              'Brandon Camp': [Movie(title='Love Happens', year=2009, score=5.6)],
#              'Kevin Tancharoen': [Movie(title='Fame', year=2009, score=5.0),
#               Movie(title='Glee: The 3D Concert Movie', year=2011, score=5.4)],
#              'Nicholas Hytner': [Movie(title='Center Stage', year=2000, score=6.7),
#               Movie(title='The Object of My Affection', year=1998, score=6.0),
#               Movie(title='The History Boys', year=2006, score=6.9)],
#              'Bart Freundlich': [Movie(title='Catch That Kid', year=2004, score=5.2),
#               Movie(title='Trust the Man', year=2005, score=5.7)],
#              'William A. Fraker': [Movie(title='The Legend of the Lone Ranger', year=1981, score=5.0)],
#              'John Boorman': [Movie(title='The Tailor of Panama', year=2001, score=6.1),
#               Movie(title='Exorcist II: The Heretic', year=1977, score=3.7),
#               Movie(title='Point Blank', year=1967, score=7.4)],
#              ...})
